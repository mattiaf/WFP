# %% [markdown]
# # OECD Aid statistics
#
# Downloaded all aids by recipients from http://stats.oecd.org/qwids/  - results.csv

# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
OECD=pd.read_csv('results.csv')
OECD.head(3) # columns are a bit fucked...
# Out:
#                         Unnamed: 0  Time Period     1960     1961     1962  \
# 0                     Recipient(s)          NaN      NaN      NaN      NaN
# 1                   All Recipients          NaN  4254.86  5219.89  5440.11
# 2  All Developing Countries, Total          NaN  4254.86  5219.89  5440.11
#
#       1963     1964    1965     1966     1967     ...           2006  \
# 0      NaN      NaN     NaN      NaN      NaN     ...            NaN
# 1  5962.44  5835.85  6243.7  6416.38  6624.13     ...      136052.95
# 2  5962.44  5835.85  6243.7  6416.38  6624.13     ...      107340.64
#
#         2007       2008       2009       2010       2011       2012  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1  140289.69  164329.69  164857.81  170597.05  183230.78  172754.52
# 2  108488.41  127918.67  127232.96   131340.2  141560.08  132737.88
#
#         2013       2014 Unnamed: 57
# 0        NaN        NaN         NaN
# ...

# %%
OECD=pd.read_csv('results.csv', skiprows=1)
OECD.head(3) 
OECD.index=OECD['Unnamed: 0']
OECD=OECD.transpose()
OECD=OECD.drop(OECD.index[[0,1]])
OECD.head()
# Out:
# Unnamed: 0 Recipient(s) All Recipients All Developing Countries, Total  \
# 1960                NaN        4254.86                         4254.86
# 1961                NaN        5219.89                         5219.89
# 1962                NaN        5440.11                         5440.11
# 1963                NaN        5962.44                         5962.44
# 1964                NaN        5835.85                         5835.85
#
# Unnamed: 0 All Multilateral Recipients, Total Afghanistan Albania Algeria  \
# 1960                                       ..       17.18      ..  355.05
# 1961                                       ..       34.67      ..  437.91
# 1962                                       ..       16.93      ..  397.63
# 1963                                       ..       36.67      ..  281.91
# 1964                                       ..       46.17      ..  227.84
#
# Unnamed: 0 Angola Anguilla Antigua and Barbuda ... Other Multilateral  \
# ...

# %% [markdown]
# ## Total Amount of Aid per Recipient Country

# %%
OECD[['Niger','Yemen','Somalia']].convert_objects(convert_numeric=True).plot()
plt.ylabel('Aid [USD millions]')
# Out:
# /Users/mattia/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   if __name__ == '__main__':
